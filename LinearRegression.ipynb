# %%
# Linear Regression with Pytorch

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a class for the model
class LinearRegression(nn.Module):
    def __init__(self):
        super(LinearRegression, self).__init__()
        self.linear = nn.Linear(1, 1)

    def forward(self, x):
        return self.linear(x)

    # Plot the data and the model
    def plot(self, x, y):
        plt.plot(x, y, 'o', label='$(x^{(i)}, y^{(i)})$')
        plt.xlabel('x')
        plt.ylabel('y')
        plt.plot(x, self.forward(x).data.numpy(), label='$\\hat y = xW+b$')
        plt.legend()
        plt.show()

    # Plot the loss real time during training
    def plot_loss(self, loss):
        plt.plot(loss)
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.show()

# %%
# Create the model
model = LinearRegression()

# Create the optimizer
optimizer = optim.SGD(model.parameters(), lr=0.01)

# Create the loss function
criterion = nn.MSELoss()

# %%
# Create the data
x = torch.randn(100, 1) * 10
y = x + 3 * torch.randn(100, 1)

# %%
# Train the model
losses = []
epochs = 100
for i in range(epochs):
    y_pred = model.forward(x)
    loss = criterion(y_pred, y)
    losses.append(loss.item())
    print('Epoch: ', i, 'Loss: ', loss.item())
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# Epoch:  0 Loss:  143.4041748046875
# Epoch:  1 Loss:  138.58148193359375
# Epoch:  2 Loss:  133.92942810058594
# Epoch:  3 Loss:  129.44180297851562
# Epoch:  4 Loss:  125.11279296875
# Epoch:  5 Loss:  120.93692016601562
# Epoch:  6 Loss:  116.90876007080078
# Epoch:  7 Loss:  113.02310180664062
# Epoch:  8 Loss:  109.27477264404297
# Epoch:  9 Loss:  105.65889739990234
# Epoch:  10 Loss:  102.17100524902344
# Epoch:  11 Loss:  98.8063735961914
# Epoch:  12 Loss:  95.56074523925781
# Epoch:  13 Loss:  92.42986297607422
# Epoch:  14 Loss:  89.40974426269531
# Epoch:  15 Loss:  86.49634552001953
# Epoch:  16 Loss:  83.68598937988281
# Epoch:  17 Loss:  80.97502136230469
# Epoch:  18 Loss:  78.35994720458984
# Epoch:  19 Loss:  75.83734893798828
# Epoch:  20 Loss:  73.40386962890625
# Epoch:  21 Loss:  71.0564956665039
# Epoch:  22 Loss:  68.7921371459961
# Epoch:  23 Loss:  66.60790252685547
# Epoch:  24 Loss:  64.50083923339844
# Epoch:  25 Loss:  62.468231201171875
# Epoch:  26 Loss:  60.507591247558594
# Epoch:  27 Loss:  58.61623001098633
# Epoch:  28 Loss:  56.791778564453125
# Epoch:  29 Loss:  55.031829833984375
# Epoch:  30 Loss:  53.33415222167969
# Epoch:  31 Loss:  51.696495056152344
# Epoch:  32 Loss:  50.11668014526367
# Epoch:  33 Loss:  48.5927848815918
# Epoch:  34 Loss:  47.122745513916016
# Epoch:  35 Loss:  45.704654693603516
# Epoch:  36 Loss:  44.33674621582031
# Epoch:  37 Loss:  43.017234802246094
# Epoch:  38 Loss:  41.744354248046875
